# %%
import matplotlib.pyplot as plt
import seaborn as sns
import run

# %%
df = run.load_df()
df.groupby(["CC", "O"]).describe()
# Out:
#         GFLOPS                                                               \
#          count      mean       std       min       25%       50%        75%
# CC    O
# clang 0    4.0  1.211046  0.829216  0.621228  0.682650  0.904716   1.433112
#       1    4.0  3.058059  2.625769  0.782305  0.785955  3.020493   5.292597
#       2    4.0  7.071835  5.786844  2.338726  2.344105  5.901605  10.629336
#       3    4.0  7.077269  5.866162  2.285744  2.325251  5.845140  10.597159
# gcc   0    4.0  1.166740  0.755437  0.494373  0.522068  1.164706   1.809378
#       1    4.0  2.936273  2.515403  0.749583  0.762580  2.912246   5.085938
#       2    4.0  6.906803  5.914613  2.029233  2.197794  5.635667  10.344676
#       3    4.0  8.264806  4.921047  2.453798  6.256084  8.080234  10.088955
#
#
#                max
# CC    O
# clang 0   2.413525
#       1   5.408944
#       2  14.145405
#       3  14.333052
# gcc   0   1.843175
#       1   5.171017
#       2  14.326646
#       3  14.444958

# %%
g = sns.catplot(
    x="CC", y="GFLOPS", col="Implementation",
    data=df, saturation=.5, hue="O",
    kind="bar", ci=None, aspect=.6)

# %%
fig, axes = plt.subplots(4, 1, figsize=(9, 5), sharex=True)



fig.tight_layout()
