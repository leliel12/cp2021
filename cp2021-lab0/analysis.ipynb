# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import run

# %%
df = run.load_df().fillna('')
df.groupby(["CC", "O", "flags"]).describe()
# Out:
#                       GFLOPS                                          \
#                        count      mean       std       min       25%
# CC    O flags
# clang 0                  4.0  0.787065  0.242676  0.543980  0.603269
#         -march=native    4.0  1.073702  0.640691  0.528362  0.540857
#       1                  4.0  2.706518  2.358911  0.617585  0.696476
#         -march=native    4.0  2.648675  2.243875  0.698063  0.709397
#       2                  4.0  6.255143  5.298458  2.102752  2.129814
#         -march=native    4.0  6.630822  5.730339  2.114394  2.121812
#       3                  4.0  6.311509  5.371962  2.114144  2.120320
#         -march=native    4.0  6.429521  5.508080  2.119490  2.131548
# gcc   0                  4.0  1.053338  0.702475  0.393930  0.482552
#         -march=native    4.0  1.010156  0.707088  0.400047  0.404412
#       1                  4.0  2.632834  2.219073  0.697524  0.720554
# ...

# %%
df["OF"] = df.apply(axis="columns", func=lambda r: f"{r.O}{r['flags']}")


g = sns.catplot(
    x="CC", y="GFLOPS", col="Implementation",
    data=df, saturation=.5, hue="OF", legend_out=True,
    kind="bar", ci=None, aspect=.6) 

# plt.tight_layout()
